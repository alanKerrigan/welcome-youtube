# %% [markdown]
# <a href="https://colab.research.google.com/github/alanKerrigan/welcome-youtube/blob/main/doctr/quicktour.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Looking for some examples on how to use docTR for OCR-related tasks? You've come to the right place 😀

# %% [markdown]
# # Installation
#
# Install all the dependencies to make the most out of docTR. The project provides two main [installation](https://mindee.github.io/doctr/latest/installing.html) streams: one for stable release, and developer mode.

# %% [markdown]
# ## Latest stable release
#
# This will install the last stable release that was published by our teams on pypi. It is expected to provide a clean and non-buggy experience for all users.

# %%
# TensorFlow
# !pip install python-doctr[tf,viz]

# PyTorch
# First we have to uninstall the preinstalled tensorflow version if we want to work with PyTorch as backend
# because the env variables USE_TORCH=1 / USE_TF=1 doesn't have an effect in Colab
# !pip uninstall -y tensorflow
# !pip install python-doctr[torch,viz]
# Out:
# Found existing installation: tensorflow 2.18.0
# Uninstalling tensorflow-2.18.0:
#   Successfully uninstalled tensorflow-2.18.0
# Collecting python-doctr[torch,viz]
#   Downloading python_doctr-0.12.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: numpy<3.0.0,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from python-doctr[torch,viz]) (2.0.2)
# Requirement already satisfied: scipy<2.0.0,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from python-doctr[torch,viz]) (1.15.3)
# Requirement already satisfied: h5py<4.0.0,>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from python-doctr[torch,viz]) (3.14.0)
# Requirement already satisfied: opencv-python<5.0.0,>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from python-doctr[torch,viz]) (4.11.0.86)
# Collecting pypdfium2<5.0.0,>=4.11.0 (from python-doctr[torch,viz])
#   Downloading pypdfium2-4.30.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 2.5 MB/s eta 0:00:00
# Collecting pyclipper<2.0.0,>=1.2.0 (from python-doctr[torch,viz])
#   Downloading pyclipper-1.3.0.post6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Requirement already satisfied: shapely<3.0.0,>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from python-doctr[torch,viz]) (2.1.1)
# Collecting langdetect<2.0.0,>=1.0.9 (from python-doctr[torch,viz])
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 24.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting rapidfuzz<4.0.0,>=3.0.0 (from python-doctr[torch,viz])
#   Downloading rapidfuzz-3.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from python-doctr[torch,viz]) (0.33.0)
# Requirement already satisfied: Pillow>=9.2.0 in /usr/local/lib/python3.11/dist-packages (from python-doctr[torch,viz]) (11.2.1)
# Requirement already satisfied: defusedxml>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from python-doctr[torch,viz]) (0.7.1)
# Collecting anyascii>=0.3.2 (from python-doctr[torch,viz])
#   Downloading anyascii-0.3.2-py3-none-any.whl.metadata (1.5 kB)
# Collecting validators>=0.18.0 (from python-doctr[torch,viz])
#   Downloading validators-0.35.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: tqdm>=4.30.0 in /usr/local/lib/python3.11/dist-packages (from python-doctr[torch,viz]) (4.67.1)
# Requirement already satisfied: torch<3.0.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from python-doctr[torch,viz]) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.15.0 in /usr/local/lib/python3.11/dist-packages (from python-doctr[torch,viz]) (0.21.0+cu124)
# Collecting onnx<3.0.0,>=1.12.0 (from python-doctr[torch,viz])
#   Downloading onnx-1.18.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.9 kB)
# Requirement already satisfied: matplotlib>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from python-doctr[torch,viz]) (3.10.0)
# Collecting mplcursors>=0.3 (from python-doctr[torch,viz])
#   Downloading mplcursors-0.6-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr[torch,viz]) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr[torch,viz]) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr[torch,viz]) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr[torch,viz]) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr[torch,viz]) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr[torch,viz]) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr[torch,viz]) (1.1.5)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from langdetect<2.0.0,>=1.0.9->python-doctr[torch,viz]) (1.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.0->python-doctr[torch,viz]) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.0->python-doctr[torch,viz]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.0->python-doctr[torch,viz]) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.0->python-doctr[torch,viz]) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.0->python-doctr[torch,viz]) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.0->python-doctr[torch,viz]) (2.9.0.post0)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.11/dist-packages (from onnx<3.0.0,>=1.12.0->python-doctr[torch,viz]) (5.29.5)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.0.0->python-doctr[torch,viz]) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.0.0->python-doctr[torch,viz]) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch<3.0.0,>=2.0.0->python-doctr[torch,viz])
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch<3.0.0,>=2.0.0->python-doctr[torch,viz])
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch<3.0.0,>=2.0.0->python-doctr[torch,viz])
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<3.0.0,>=2.0.0->python-doctr[torch,viz])
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<3.0.0,>=2.0.0->python-doctr[torch,viz])
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<3.0.0,>=2.0.0->python-doctr[torch,viz])
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<3.0.0,>=2.0.0->python-doctr[torch,viz])
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<3.0.0,>=2.0.0->python-doctr[torch,viz])
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<3.0.0,>=2.0.0->python-doctr[torch,viz])
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.0.0->python-doctr[torch,viz]) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.0.0->python-doctr[torch,viz]) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.0.0->python-doctr[torch,viz]) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<3.0.0,>=2.0.0->python-doctr[torch,viz])
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.0.0->python-doctr[torch,viz]) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.0.0->python-doctr[torch,viz]) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3.0.0,>=2.0.0->python-doctr[torch,viz]) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3.0.0,>=2.0.0->python-doctr[torch,viz]) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub<1.0.0,>=0.20.0->python-doctr[torch,viz]) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub<1.0.0,>=0.20.0->python-doctr[torch,viz]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub<1.0.0,>=0.20.0->python-doctr[torch,viz]) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub<1.0.0,>=0.20.0->python-doctr[torch,viz]) (2025.6.15)
# Downloading anyascii-0.3.2-py3-none-any.whl (289 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.9/289.9 kB 16.4 MB/s eta 0:00:00
# Downloading mplcursors-0.6-py3-none-any.whl (20 kB)
# Downloading onnx-1.18.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 54.2 MB/s eta 0:00:00
# Downloading pyclipper-1.3.0.post6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (969 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 969.6/969.6 kB 43.6 MB/s eta 0:00:00
# Downloading pypdfium2-4.30.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 55.8 MB/s eta 0:00:00
# Downloading rapidfuzz-3.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 49.8 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 69.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 70.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 52.6 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.5 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.2 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 75.2 MB/s eta 0:00:00
# Downloading validators-0.35.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.7/44.7 kB 3.1 MB/s eta 0:00:00
# Downloading python_doctr-0.12.0-py3-none-any.whl (377 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.2/377.2 kB 24.2 MB/s eta 0:00:00
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993223 sha256=9c0afe92cc0ef0a749e0a2e140e8b0074b68e9e429736d782a1e07f5b00d2de8
#   Stored in directory: /root/.cache/pip/wheels/0a/f2/b2/e5ca405801e05eb7c8ed5b3b4bcf1fcabcd6272c167640072e
# Successfully built langdetect
# Installing collected packages: pyclipper, validators, rapidfuzz, pypdfium2, onnx, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, langdetect, anyascii, nvidia-cusparse-cu12, nvidia-cudnn-cu12, python-doctr, nvidia-cusolver-cu12, mplcursors
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed anyascii-0.3.2 langdetect-1.0.9 mplcursors-0.6 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 onnx-1.18.0 pyclipper-1.3.0.post6 pypdfium2-4.30.1 python-doctr-0.12.0 rapidfuzz-3.13.0 validators-0.35.0

# %% [markdown]
# ## From source
#
# Before being staged for a stable release, we constantly iterate on the community feedback to improve the library. Bug fixes and performance improvements are regularly pushed to the project Git repository. Using this installation method, you will access all the latest features that have not yet made their way to a pypi release!

# %%
# Install the most up-to-date version from GitHub

# TensorFlow
# !pip install python-doctr[tf,viz]@git+https://github.com/mindee/doctr.git

# PyTorch
# First we have to uninstall the preinstalled tensorflow version if we want to work with PyTorch as backend
# because the env variables USE_TORCH=1 / USE_TF=1 doesn't have an effect in Colab
# !pip uninstall -y tensorflow
# !pip install python-doctr[torch,viz]@git+https://github.com/mindee/doctr.git
# Out:
# WARNING: Skipping tensorflow as it is not installed.
# Collecting python-doctr@ git+https://github.com/mindee/doctr.git (from python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git)
#   Cloning https://github.com/mindee/doctr.git to /tmp/pip-install-ahzbhviw/python-doctr_b4639ec3dd35420aae494ca3e2b199cc
#   Running command git clone --filter=blob:none --quiet https://github.com/mindee/doctr.git /tmp/pip-install-ahzbhviw/python-doctr_b4639ec3dd35420aae494ca3e2b199cc
#   Resolved https://github.com/mindee/doctr.git to commit 9e083c4e6cad75335998f671c892c07ac4e0fb26
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy<3.0.0,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (2.0.2)
# Requirement already satisfied: scipy<2.0.0,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (1.15.3)
# Requirement already satisfied: h5py<4.0.0,>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (3.14.0)
# Requirement already satisfied: opencv-python<5.0.0,>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (4.11.0.86)
# Requirement already satisfied: pypdfium2<5.0.0,>=4.11.0 in /usr/local/lib/python3.11/dist-packages (from python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (4.30.1)
# Requirement already satisfied: pyclipper<2.0.0,>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (1.3.0.post6)
# Requirement already satisfied: shapely<3.0.0,>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (2.1.1)
# Requirement already satisfied: langdetect<2.0.0,>=1.0.9 in /usr/local/lib/python3.11/dist-packages (from python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (1.0.9)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (3.13.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (0.33.0)
# Requirement already satisfied: Pillow>=9.2.0 in /usr/local/lib/python3.11/dist-packages (from python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (11.2.1)
# Requirement already satisfied: defusedxml>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (0.7.1)
# Requirement already satisfied: anyascii>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (0.3.2)
# Requirement already satisfied: validators>=0.18.0 in /usr/local/lib/python3.11/dist-packages (from python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (0.35.0)
# Requirement already satisfied: tqdm>=4.30.0 in /usr/local/lib/python3.11/dist-packages (from python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (4.67.1)
# Requirement already satisfied: torch<3.0.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.15.0 in /usr/local/lib/python3.11/dist-packages (from python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (0.21.0+cu124)
# Requirement already satisfied: onnx<3.0.0,>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (1.18.0)
# Requirement already satisfied: matplotlib>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (3.10.0)
# Requirement already satisfied: mplcursors>=0.3 in /usr/local/lib/python3.11/dist-packages (from python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (0.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (1.1.5)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from langdetect<2.0.0,>=1.0.9->python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (1.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.0->python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.0->python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.0->python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.0->python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.0->python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.0->python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (2.9.0.post0)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.11/dist-packages (from onnx<3.0.0,>=1.12.0->python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (5.29.5)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.0.0->python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.0.0->python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.0.0->python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.0.0->python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.0.0->python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.0.0->python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.0.0->python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.0.0->python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.0.0->python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.0.0->python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.0.0->python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.0.0->python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.0.0->python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.0.0->python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.0.0->python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.0.0->python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.0.0->python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3.0.0,>=2.0.0->python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3.0.0,>=2.0.0->python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub<1.0.0,>=0.20.0->python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub<1.0.0,>=0.20.0->python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub<1.0.0,>=0.20.0->python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub<1.0.0,>=0.20.0->python-doctr@ git+https://github.com/mindee/doctr.git->python-doctr[torch,viz]@ git+https://github.com/mindee/doctr.git) (2025.6.15)
# Building wheels for collected packages: python-doctr
#   Building wheel for python-doctr (pyproject.toml) ... done
#   Created wheel for python-doctr: filename=python_doctr-0.12.1a0-py3-none-any.whl size=377214 sha256=baed6ae579101e41ded854fa83b4cf6dd10cf76f66e056c60e790dbbf9a7efbb
#   Stored in directory: /tmp/pip-ephem-wheel-cache-62zrtqp0/wheels/3f/0f/e1/d43cefe2c76f6d8be8263171180d048b609a4de1a2595b1fe4
# Successfully built python-doctr
# Installing collected packages: python-doctr
#   Attempting uninstall: python-doctr
#     Found existing installation: python-doctr 0.12.0
#     Uninstalling python-doctr-0.12.0:
#       Successfully uninstalled python-doctr-0.12.0
# Successfully installed python-doctr-0.12.1a0

# %% [markdown]
# # Basic usage
#
# We're going to review the main features of docTR 🎁
# And for you to have a proper overview of its capabilities, we will need some free fonts for a proper output visualization:

# %%
# Install some free fonts for result rendering
# !sudo apt-get install fonts-freefont-ttf -y
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-freefont-ttf
# 0 upgraded, 1 newly installed, 0 to remove and 35 not upgraded.
# Need to get 2,388 kB of archives.
# After this operation, 6,653 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-freefont-ttf all 20120503-10build1 [2,388 kB]
# Fetched 2,388 kB in 1s (2,897 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-freefont-ttf.
# (Reading database ... 126308 files and directories currently installed.)
# Preparing to unpack .../fonts-freefont-ttf_20120503-10build1_all.deb ...
# Unpacking fonts-freefont-ttf (20120503-10build1) ...
# Setting up fonts-freefont-ttf (20120503-10build1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...

# %% [markdown]
# Let's take care of all the imports directly

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

from doctr.io import DocumentFile
from doctr.models import ocr_predictor

# %% [markdown]
# For the next steps, we will need a proper PDF document that will be used to showcase the library features

# %%
# Download a sample
# !wget https://eforms.com/download/2019/01/Cash-Payment-Receipt-Template.pdf
# !wget /content/BA_SemiHaz.pdf
# Read the file
doc = DocumentFile.from_pdf("Cash-Payment-Receipt-Template.pdf")
print(f"Number of pages: {len(doc)}")
# Out:
# /content/BA_SemiHaz.pdf: Scheme missing.
# Number of pages: 1

# %%
# Download a sample
# !wget https://eforms.com/download/2019/01/Cash-Payment-Receipt-Template.pdf
# !wget /content/BA_SemiHaz.pdf
# Read the file
doc = DocumentFile.from_pdf("BA_SemiHaz.pdf")
print(f"Number of pages: {len(doc)}")
# Out:
# Number of pages: 1

# %% [markdown]
# docTR is, under the hood, running Deep Learning models to perform the different tasks it supports. Those models were built and trained with very popular frameworks for maximum compatibility (you will be pleased to know that you can switch from [PyTorch](https://pytorch.org/) to [TensorFlow](https://www.tensorflow.org/) without noticing any difference for you). By default, our high-level API sets the best default values so that you get high performing models without having to know anything about it. All of this is wrapper in a `Predictor` object, which will take care of pre-processing, model inference and post-processing for you ⚡
#
# Let's instantiate one!

# %%
# Instantiate a pretrained model
predictor = ocr_predictor(pretrained=True)

# %% [markdown]
# By default, PyTorch model provides a nice visual description of a model, which is handy when it comes to debugging or knowing what you just created. We also added a similar feature for TensorFlow backend so that you don't miss on this nice assistance.
#
# Let's dive into this model 🕵

# %%
# Display the architecture
print(predictor)
# Out:
# OCRPredictor(
#   (det_predictor): DetectionPredictor(
#     (pre_processor): PreProcessor(
#       (resize): Resize(output_size=(1024, 1024), interpolation='bilinear', preserve_aspect_ratio=True, symmetric_pad=True)
#       (normalize): Normalize(mean=(0.798, 0.785, 0.772), std=(0.264, 0.2749, 0.287))
#     )
#     (model): FAST()
#   )
#   (reco_predictor): RecognitionPredictor(
#     (pre_processor): PreProcessor(
#       (resize): Resize(output_size=(32, 128), interpolation='bilinear', preserve_aspect_ratio=True, symmetric_pad=False)
#       (normalize): Normalize(mean=(0.694, 0.695, 0.693), std=(0.299, 0.296, 0.301))
#     )
#     (model): CRNN(
#       (feat_extractor): Sequential(
#         (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#         (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (9): ReLU(inplace=True)
#         (10): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (12): ReLU(inplace=True)
#         (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (14): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (15): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (16): ReLU(inplace=True)
#         (17): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (18): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (19): ReLU(inplace=True)
#         (20): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (21): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (22): ReLU(inplace=True)
#         (23): MaxPool2d(kernel_size=(2, 1), stride=(2, 1), padding=0, dilation=1, ceil_mode=False)
#         (24): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (25): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (26): ReLU(inplace=True)
#         (27): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (28): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (29): ReLU(inplace=True)
#         (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (31): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (32): ReLU(inplace=True)
#         (33): MaxPool2d(kernel_size=(2, 1), stride=(2, 1), padding=0, dilation=1, ceil_mode=False)
#         (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (35): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (36): ReLU(inplace=True)
#         (37): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (38): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (39): ReLU(inplace=True)
#         (40): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (41): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (42): ReLU(inplace=True)
#         (43): MaxPool2d(kernel_size=(2, 1), stride=(2, 1), padding=0, dilation=1, ceil_mode=False)
#       )
#       (decoder): LSTM(512, 128, num_layers=2, batch_first=True, bidirectional=True)
#       (linear): Linear(in_features=256, out_features=127, bias=True)
#       (postprocessor): CTCPostProcessor(vocab_size=126)
#     )
#   )
# )

# %% [markdown]
# Here we are inspecting the most complex (and high-level) object of docTR API: an OCR predictor. Since docTR achieves Optical Character Recognition by first localizing textual elements (Text Detection), then extracting the corresponding text from each location (Text Recognition), the OCR Predictor wraps two sub-predictors: one for text detection, and the other for text recognition.

# %% [markdown]
# ## Basic inference
#
# It looks quite complex, isn't it?
# Well that will not prevent you from easily get nice results. See for yourself:

# %%
result = predictor(doc)

# %% [markdown]
# ## Prediction visualization
#
# If you rightfully prefer to see the results with your eyes, docTR includes a few visualization features. We will first overlay our predictions on the original document:

# %%
result.show()

# %% [markdown]
# Looks accurate!
# But we can go further: if the extracted information is correctly structured, we should be able to recreate the page entirely. So let's do this 🎨

# %%
synthetic_pages = result.synthesize()
plt.imshow(synthetic_pages[0]); plt.axis('off'); plt.show()

# %% [markdown]
# ## Exporting results
#
# OK, so the predictions are relevant, but how would you integrate this into your own document processing pipeline? Perhaps you're not using Python at all?
#
# Well, if you happen to be using JSON or XML exports, they are already supported 🤗

# %%
# JSON export
json_export = result.export()
print(json_export)
# Out:
# {'pages': [{'page_idx': 0, 'dimensions': (840, 1191), 'orientation': {'value': None, 'confidence': None}, 'language': {'value': None, 'confidence': None}, 'blocks': [{'geometry': ((np.float64(0.0234375), np.float64(0.09568917410714284)), (np.float64(0.9892578125), np.float64(0.9749267578125))), 'objectness_score': 0.7974687240561661, 'lines': [{'geometry': ((np.float64(0.033203125), np.float64(0.09568917410714284)), (np.float64(0.544921875), np.float64(0.15107421875))), 'objectness_score': 0.8686532576878866, 'words': [{'value': 'PLATTONAL', 'confidence': 0.8747026522954305, 'geometry': ((np.float64(0.033203125), np.float64(0.10261230468749999)), (np.float64(0.3505859375), np.float64(0.14968959263392856))), 'objectness_score': 0.8569950461387634, 'crop_orientation': {'value': 0, 'confidence': None}}, {'value': 'TM', 'confidence': 0.9977867603302002, 'geometry': ((np.float64(0.3623046875), np.float64(0.09568917410714284)), (np.float64(0.4072265625), np.float64(0.13168945312500002))), 'objectness_score': 0.8632151484489441, 'crop_orientation': {'value': 0, 'confidence': None}}, {'value': '1118', 'confidence': 0.992731511592865, 'geometry': ((np.float64(0.4326171875), np.float64(0.09984305245535713)), (np.float64(0.544921875), np.float64(0.15107421875))), 'objectness_score': 0.8857495784759521, 'crop_orientation': {'value': 0, 'confidence': None}}]}, {'geometry': ((np.float64(0.6708984375), np.float64(0.10261230468749999)), (np.float64(0.951171875), np.float64(0.1358433314732143))), 'objectness_score': 0.8326837619145712, 'words': [{'value': 'Material', 'confidence': 0.579171359539032, 'geometry': ((np.float64(0.6708984375), np.float64(0.10399693080357142)), (np.float64(0.7705078125), np.float64(0.13307407924107145))), 'objectness_score': 0.8402355313301086, 'crop_orientation': {'value': 0, 'confidence': None}}, {'value': 'Nr.:', 'confidence': 0.9984580278396606, 'geometry': ((np.float64(0.779296875), np.float64(0.10261230468749999)), (np.float64(0.82421875), np.float64(0.1358433314732143))), 'objectness_score': 0.8351677060127258, 'crop_orientation': {'value': 0, 'confidence': None}}, {'value': '15064347', 'confidence': 0.5935286283493042, 'geometry': ((np.float64(0.8349609375), np.float64(0.10399693080357142)), (np.float64(0.951171875), np.float64(0.13307407924107145))), 'objectness_score': 0.8226480484008789, 'crop_orientation': {'value': 0, 'confidence': None}}]}, {'geometry': ((np.float64(0.0234375), np.float64(0.18845912388392855)), (np.float64(0.611328125), np.float64(0.21615164620535715))), 'objectness_score': 0.7916730429444995, 'words': [{'value': 'CS:', 'confidence': 0.9977725148200989, 'geometry': ((np.float64(0.0234375), np.float64(0.18845912388392855)), (np.float64(0.048828125), np.float64(0.21199776785714286))), 'objectness_score': 0.7449418306350708, 'crop_orientation': {'value': 0, 'confidence': None}}, {'value': 'Nevyzaduje', 'confidence': 0.9978467226028442, 'geometry': ((np.float64(0.0498046875), np.float64(0.18984374999999998)), (np.float64(0.1162109375), np.float64(0.21476702008928572))), 'objectness_score': 0.8730884790420532, 'crop_orientation': {'value': 0, 'confidence': None}}, {'value': 'se', 'confidence': 0.9996922016143799, 'geometry': ((np.float64(0.1171875), np.float64(0.19399762834821427)), (np.float64(0.1337890625), np.float64(0.21061314174107143))), 'objectness_score': 0.768905520439148, 'crop_orientation': {'value': 0, 'confidence': None}}, {'value': 'Zadny', 'confidence': 0.5941320061683655, 'geometry': ((np.float64(0.1328125), np.float64(0.18845912388392855)), (np.float64(0.169921875), np.float64(0.21615164620535715))), 'objectness_score': 0.7620388269424438, 'crop_orientation': {'value': 0, 'confidence': None}}, {'value': 'vystrazny', 'confidence': 0.5260552763938904, 'geometry': ((np.float64(0.1708984375), np.float64(0.18984374999999998)), (np.float64(0.224609375), np.float64(0.21476702008928572))), 'objectness_score': 0.8729982972145081, 'crop_orientation': {'value': 0, 'confidence': None}} ...

# %%
# XML export
xml_output = result.export_as_xml()
print(xml_output[0][0])
# Out:
# b'<html xmlns="http://www.w3.org/1999/xhtml" xml:lang="en"><head><title>docTR - XML export (hOCR)</title><meta http-equiv="Content-Type" content="text/html; charset=utf-8" /><meta name="ocr-system" content="python-doctr 0.12.1a0" /><meta name="ocr-capabilities" content="ocr_page ocr_carea ocr_par ocr_line ocrx_word" /></head><body><div class="ocr_page" id="page_1" title="image; bbox 0 0 1191 840; ppageno 0"><div class="ocr_carea" id="block_1" title="bbox 28 80                     1178 819"><p class="ocr_par" id="par_1" title="bbox 28 80                     1178 819"><span class="ocr_line" id="line_1" title="bbox 40 80                         649 127;                         baseline 0 0; x_size 0; x_descenders 0; x_ascenders 0"><span class="ocrx_word" id="word_1" title="bbox 40 86                             418 126;                             x_wconf 87">PLATTONAL</span><span class="ocrx_word" id="word_2" title="bbox 432 80                             485 111;                             x_wconf 100">TM</span><span class="ocrx_word" id="word_3" title="bbox 515 84                             649 127;                             x_wconf 99">1118</span></span><span class="ocr_line" id="line_2" title="bbox 799 86                         1133 114;                         baseline 0 0; x_size 0; x_descenders 0; x_ascenders 0"><span class="ocrx_word" id="word_4" title="bbox 799 87                             918 112;                             x_wconf 58">Material</span><span class="ocrx_word" id="word_5" title="bbox 928 86                             982 114;                             x_wconf 100">Nr.:</span><span class="ocrx_word" id="word_6" title="bbox 994 87                             1133 112;                             x_wconf 59">15064347</span></span><span class="ocr_line" id="line_3" title="bbox 28 158                         728 182;                         baseline 0 0; x_size 0; x_descenders 0; x_ascenders 0"><span class="ocrx_word" id="word_7" title="bbox 28 158                             58 178;                             x_wconf 100">CS:</span><span class="ocrx_word" id="word_8" title="bbox 59 159                             138 180;                             x_wconf 100">Nevyzaduje</span><span class="ocrx_word" id="word_9" title="bbox 140 163                             159 177;                             x_wconf 100">se</span><span class="ocrx_word" id="word_10" title="bbox 158 158                             202 182;                             x_wconf 59">Zadny</span><span class="ocrx_word" id="word_11" title="bbox 204 159                             268 180;                             x_wconf 53">vystrazny</span><span class="ocrx_word" id="word_12" title="bbox 269 159                             319 182;                             x_wconf 99">symbol</span><span class="ocrx_word" id="word_13" title="bbox 321 159                             422 180;                             x_wconf 97">nebezpecnosti,</span><span class="ocrx_word" id="word_14" title="bbox 423 159                             466 177;                             x_wconf 85">zadn\xc3\xa9</span><span class="ocrx_word" id="word_15" title="bbox 469 159                             522 180;                             x_wconf 99">signalni</span><span class="ocrx_word" id="word_16" title="bbox 522 158                             565 180;                             x_wconf 99">slovo,</span><span class="ocrx_word" id="word_17" title="bbox 565 159                             609 177;                             x_wconf 83">zadn\xc3\xa9</span><span class="ocrx_word" id="word_18" title="bbox 611 159                             682 177;                             x_wconf 97">standardni</span><span class="ocrx_word" id="word_19" title="bbox 683 158                             716 182;                             x_wconf 97">v\xc3\xa9ty</span><span class="ocrx_word" id="word_20" title="bbox 714 161                             728 179;              ...

# %% [markdown]
# Or if you only need the extracted plain text

# %%
string_result = result.render()
print(string_result)
# Out:
# PLATTONAL TM 1118
# Material Nr.: 15064347
# CS: Nevyzaduje se Zadny vystrazny symbol nebezpecnosti, zadné signalni slovo, zadné standardni véty 0
# I
# nebezpecnosti, zadné pokyny pro bezpecné zachâzeni. Obsahuje Smés 5-chlor-2-methyl-3 (2H) isothiazolu. S
# 2-Methyl-3 (2H) isothiazolonem. Muze vyvolat alergickou reakci. Na vyzadani jel k dispozici bezpecnostni list.
# EN: No hazard pictogram, no signal word, no hazard statement(s), no precautionary statement(s) required.
# Contains 5-Chloro-2-methyl-3(2H)isothiazolone mixt. with 2-Methyl-3(2HJisothiazolone. May produce an allergic
# reaction. Safety data sheet available on request.
# Batch: B15064347
# ES: No es necesario pictograma(s) de peligro, palabra de advertencia, indicacion(es) de peligro ni consejos de
# prudencia. Contiene Masa de reaccion de 5-cloro-2-metil-2H-isotiazol-3-ona y 2-metil-2H-isotiazol-3-ona (3:1).
# Puede provocar una reaccion alérgica. Puede solicitarse la ficha de datos de seguridad.
# FR: Pas de pictogramme de danger, pas de mention d'avertissement, pas de mention(s) de danger, pas de
# conseil(s) de prudence requis. Contient Mélange de 5-chloro-2-méthyl-3(2H)-ISothiazolone et de 2-méthyl-3(2H)-
# isothiazolone. Peut produire une réaction allergique. Fiche de données de sécurité disponible sur demande.
# IT: Nessun pittogramma di pericolo, nessuna avvertenza, nessuna indicazioneli di pericolo, nessun consiglio/i di
# Net Weight kg):1100
# prudenza richiesto. Contiene Miscela di 5-cloro-2-meti-3(2Hjisotiazolo. con 2-metil-3(2Hljisotiazolone. Pud
# provocare una reazione allergica. Scheda dati di sicurezza disponibile su richiesta.
# NO: Ingen farepiktogram, ingen varselord, ingen faresetning(er), ingen sikkerhetssetningler) kreves. Inneholder
# 5-klor-2-metyl-3(2Hlisotiazol blandet med 2-Mety-3(2Hjsoliazolon. Kan gi en allergisk reaksjon.
# Sikkerhetsdatablad er tilgjengelig pà anmodning.
# Store Between +5°C to +35°C
# Manufacture Date: 05/2025
# Best Before: 11/2025
# UFI: 2WT6-2270-319J-UPJ4
# Designed and Manufactured in the UK
# BEARDOWADAMS.
# Unique Adhesives
# BCSONE
